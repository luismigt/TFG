# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm


import seaborn as sn


import matplotlib.pyplot as plt


df=pd.read_csv('../../DATASETS/AHOGADOS/CSV/historico_inc_est_meteo_codigos_test.csv',sep='|',error_bad_lines=False)

# %%
df_stats=df[['Mes', 'Edad', 'T_med', 'T_max', 'T_min', 'Precipitaciones', 'Presion','Dir_viento', 'V_Viento', 'Nubosidad', 'ProfNievecm', 'Mortal', 'IdPronostico', 'Costa']]

# %% [raw]
# df_stats['Sexo']=df_stats['Sexo'].str.replace('Hombre','0')
# df_stats['Sexo']=df_stats['Sexo'].str.replace('Mujer','1')
# df_stats['Sexo']=df_stats['Sexo'].str.replace('Sin Datos','2')
# df_stats['Sexo']=df_stats['Sexo'].str.replace('NaN','2')
#
# df_stats['Sexo'] = df_stats['Sexo'].fillna('2')

# %%
df_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5468 entries, 0 to 5467
# Data columns (total 14 columns):
# Mes                5468 non-null float64
# Edad               4510 non-null float64
# T_med              5468 non-null float64
# T_max              5468 non-null float64
# T_min              5468 non-null float64
# Precipitaciones    5468 non-null float64
# Presion            5468 non-null float64
# Dir_viento         5463 non-null float64
# V_Viento           5468 non-null int64
# Nubosidad          5468 non-null float64
# ProfNievecm        4218 non-null float64
# Mortal             5468 non-null int64
# IdPronostico       5468 non-null int64
# Costa              5468 non-null int64
# dtypes: float64(10), int64(4)
# memory usage: 598.2 KB

# %%
#df_stats = df_stats[(df_stats['Mes'].between(6,9))]
df_stats = df_stats[(df_stats['Mes'].between(7,9))]

# %% [raw]
# corr = df_stats.set_index('Mortal').corr()
# sm.graphics.plot_corr(corr, xnames=list(corr.columns))
# plt.show()

# %%
plt.figure(figsize=(25,25))

corrMatrix = df_stats.corr()
sn.heatmap(corrMatrix, annot=True, square=True)
plt.show()

# %%
c = corrMatrix.abs()
s = c.unstack()
so = s.sort_values(ascending=False , kind="quicksort")

# %%
so=so.to_frame()

# %%
so.reset_index(inplace=True)

# %%
so.columns = ['Variable1', 'Variable2', 'correlacion']

# %%
so=so[so.Variable1 != so.Variable2]

# %%
so=so.drop_duplicates(subset=['correlacion'])

# %%
so.reset_index(inplace=True)

# %%
so.head(n=50)
# Out:
#     index        Variable1        Variable2  correlacion
# 0      11        Nubosidad      ProfNievecm     1.000000
# 1      16            T_med            T_max     0.886709
# 2      18            T_med            T_min     0.805823
# 3      20     IdPronostico           Mortal     0.541009
# 4      22            T_max            T_min     0.440893
# 5      24             Edad           Mortal     0.404656
# 6      26            T_max      ProfNievecm     0.401332
# 7      28            Costa          Presion     0.395948
# 8      30     IdPronostico             Edad     0.307704
# 9      32          Presion            T_min     0.294460
# 10     34            T_med      ProfNievecm     0.272952
# 11     36            T_max        Nubosidad     0.271234
# 12     38  Precipitaciones      ProfNievecm     0.238888
# 13     40            Costa            T_min     0.238591
# 14     42            T_min         V_Viento     0.216328
# 15     44            T_min       Dir_viento     0.215107
# 16     46            Costa            T_max     0.200285
# 17     48              Mes      ProfNievecm     0.196602
# 18     50            T_med        Nubosidad     0.195760
# 19     52            T_med          Presion     0.180991
# 20     54            T_max     IdPronostico     0.176889
# 21     56       Dir_viento         V_Viento     0.173808
# 22     58            T_med       Dir_viento     0.148531
# 23     60     IdPronostico            T_med     0.145464
# 24     62        Nubosidad              Mes     0.140869
# 25     64  Precipitaciones        Nubosidad     0.132565
# 26     66              Mes            T_max     0.131191
# 27     68            Costa           Mortal     0.122836
# 28     70            T_med              Mes     0.121683
# 29     72            T_max  Precipitaciones     0.115556
# 30     74       Dir_viento            Costa     0.114953
# 31     76        Nubosidad          Presion     0.113802
# 32     78            T_med  Precipitaciones     0.111015
# 33     80     IdPronostico        Nubosidad     0.109398
# 34     82            Costa  Precipitaciones     0.106570
# 35     84            Costa     IdPronostico     0.105323
# 36     86         V_Viento            Costa     0.097003
# 37     88           Mortal            T_max     0.092914
# 38     90          Presion           Mortal     0.084711
# 39     92           Mortal         V_Viento     0.082688
# 40     94         V_Viento     IdPronostico     0.082170
# 41     96            T_med         V_Viento     0.080095
# 42     98     IdPronostico          Presion     0.072018
# 43    100              Mes            T_min     0.068365
# 44    102  Precipitaciones            T_min     0.067361
# 45    104          Presion         V_Viento     0.063876
# 46    106              Mes          Presion     0.063773
# 47    108            T_med           Mortal     0.061555
# 48    110            Costa      ProfNievecm     0.061314
# 49    112              Mes            Costa     0.060490
